# %%
import os

# %%
os.listdir()
# Out:
# ['.git', '.ipynb_checkpoints', 'data', 'EDA.ipynb']

# %%
os.listdir('data/')
# Out:
# ['01_university_admissions_turkey_2019_2024.csv',
#  'archive.zip',
#  'departments_normalized.csv',
#  'department_avg_net_stats.csv',
#  'department_names.csv',
#  'department_placed_preferences.csv',
#  'department_placed_preference_ranks.csv',
#  'department_placed_pref_uni_type.csv',
#  'department_preferences.csv',
#  'department_preference_ranks.csv',
#  'department_stats.csv',
#  'department_tags.csv',
#  'department_years.csv',
#  'faculty_names.csv',
#  'lessons.csv',
#  'scholarship_types.csv',
#  'score_types.csv',
#  'tags.csv',
#  'universities_normalized.csv',
#  'university_cities.csv',
#  'university_types.csv',
#  'years.csv']

# %%
os.remove('data/01_university_admissions_turkey_2019_2024.csv')

# %%
os.remove('data/archive.zip')

# %%
import pandas as pd

# %%
filename = os.listdir('data/')

# %%
filename
# Out:
# ['departments_normalized.csv',
#  'department_avg_net_stats.csv',
#  'department_names.csv',
#  'department_placed_preferences.csv',
#  'department_placed_preference_ranks.csv',
#  'department_placed_pref_uni_type.csv',
#  'department_preferences.csv',
#  'department_preference_ranks.csv',
#  'department_stats.csv',
#  'department_tags.csv',
#  'department_years.csv',
#  'faculty_names.csv',
#  'lessons.csv',
#  'scholarship_types.csv',
#  'score_types.csv',
#  'tags.csv',
#  'universities_normalized.csv',
#  'university_cities.csv',
#  'university_types.csv',
#  'years.csv']

# %%
cud = %pwd

# %%
name={}
for i in range(len(filename)):
    name["df"+str(i+1)]=pd.read_csv(f'data/{filename[i]}',low_memory=False)

# %%
name['df1']
# Out:
#        program_code  department_name_id  faculty_name_id  university_id  \
# 0         103390230                   1                1            115
# 1         108690161                   2                2            147
# 2         104590132                   2                3            242
# 3         103290214                   2                4            164
# 4         109190059                   2                5            162
# ...             ...                 ...              ...            ...
# 32500     106010337                 733              275            399
# 32501     107910219                 733              275            309
# 32502     109810365                 733              275            278
# 32503     110210463                 733              275            304
# 32504     105290179                 733              275            119
#
#        score_type_id  scholarship_type_id  is_undergraduate  \
# ...
